# %%
import numpy as np
import pandas as pd

df = pd.read_csv("AMZN.csv")
money = 100

for i in range(100):

    middleband = df["Close"].iloc[-20:].mean()
    stdev = ((((df["Close"]-middleband) ** 2).sum()/20) ** 0.5)
    upperband = middleband + 2 * stdev
    lowerband = middleband - 2 * stdev
    
    if (df["Close"].iloc[-1] > upperband):
        money
